# %% [markdown]
# # Data Visualization with Python Studio
#
# At this point, you should already have connected with the rest of your group to divide up who is going to do what. Use this notebook to create your visualizations.
#
# Below we set up the dataframe with the Goodreads dataset for you. If you run this cell, you may get an error that some lines were skipped. Do not worry about that! For this studio, we want to focus on creating an effective

# %%
# Here is the setup of the dataframe. Feel free to use .info() or .head() to get a better understanding of what is inside the dataframe!

import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib import style

df = pd.read_csv("books.csv", error_bad_lines=False)

years = []

for y in df['publication_date']:
    date = y.split("/")
    years.append(date[2])

df["year"] = years
# Out:
# C:\Users\Brown\AppData\Local\Temp\ipykernel_77360\1955950391.py:9: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("books.csv", error_bad_lines=False)
# b'Skipping line 3350: expected 12 fields, saw 13\nSkipping line 4704: expected 12 fields, saw 13\nSkipping line 5879: expected 12 fields, saw 13\nSkipping line 8981: expected 12 fields, saw 13\n'

# %%
df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
# 3           eng          435        2339585               36325
# 4           eng         2690          41428                 164
#
#   publication_date        publisher  year
# 0        9/16/2006  Scholastic Inc.  2006
# 1         9/1/2004  Scholastic Inc.  2004
# 2        11/1/2003       Scholastic  2003
# 3         5/1/2004  Scholastic Inc.  2004
# 4        9/13/2004       Scholastic  2004

# %%
df.shape
# Out:
# (11123, 13)

# %%
df['year'].value_counts()
# Out:
# 2006    1700
# 2005    1260
# 2004    1069
# 2003     931
# 2002     798
#         ...
# 1947       1
# 1922       1
# 1929       1
# 1919       1
# 1940       1
# Name: year, Length: 87, dtype: int64

# %%
x = df.groupby('year')
x.first()
# Out:
#       bookID                                              title  \
# year
# 1900   37134                                Consider the Lilies
# 1913   24459                            On Duties (De Officiis)
# 1914   25692          Agricola / Germania / Dialogue on Oratory
# 1919    1440          History of the Peloponnesian War: Bk. 1-2
# 1921    1444          History of the Peloponnesian War: Bk. 5-6
# ...      ...                                                ...
# 2016    6981  When the Heart Waits: Spiritual Direction for ...
# 2017    4060  Soul Mates & Twin Flames: The Spiritual Dimens...
# 2018   11625                        Ariel: The Restored Edition
# 2019    1337                      Enthusiasm and Divine Madness
# 2020   38568                         A Quick Bite (Argeneau #1)
#
#                                                 authors  average_rating  \
# year
# 1900                  Iain Crichton Smith/Isobel Murray            3.88
# 1913                Marcus Tullius Cicero/Walter Miller            3.96
# 1914  Tacitus/Maurice Hutton/Robert Maxwell Ogilvie/...            3.95
# 1919                              Thucydides/C.F. Smith            4.32
# 1921                              Thucydides/C.F. Smith            4.35
# ...                                                 ...             ...
# 2016                                      Sue Monk Kidd            4.13
# 2017                            Elizabeth Clare Prophet            3.79
# 2018                         Sylvia Plath/Frieda Hughes            4.27
# 2019         Josef Pieper/Richard Winston/Clara Winston            4.50
# 2020                                       Lynsay Sands            3.91
#
#             isbn         isbn13 language_code    num_pages  ratings_count  \
# year
# 1900  0753812932  9780753812938           eng          144            332
# 1913  0674990331  9780674990333           eng          448            111
# 1914  0674990390  9780674990395           mul          384             87
# 1919  0674991206  9780674991200           mul          496            208
# 1921  0674991222  9780674991224           mul          400             38
# ...          ...            ...           ...          ...            ...
# 2016  0061144894  9780061144899           eng          240           2366
# 2017  0922729484  9780922729487         en-US          155            141
# 2018  0060732601  9780060732608           eng          256           3737
# 2019  189031823X  9781890318239           eng          125             26
# 2020  0060773758  9780060773755           eng          360          35275
#
#       text_reviews_count publication_date                         publisher
# year
# 1900                  33         1/1/1900                           Polygon
# 1913                  11         1/1/1913          Harvard University Press
# 1914                   7         1/1/1914          Harvard University Press
# 1919                   7         1/1/1919          Harvard University Press
# 1921                   0         1/1/1921          Harvard University Press
# ...                  ...              ...                               ...
# 2016                 231       10/11/2016                         HarperOne
# 2017                   5        8/17/2017           Summit University Press
# 2018                 283         3/6/2018  Harper Perennial Modern Classics
# 2019                   4        2/11/2019              St. Augustines Press
# 2020                1370        3/31/2020                              Avon
#
# [87 rows x 12 columns]

# %%
x = df.groupby(['year'])
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001E0E1FCA9D0>

# %%
fig1 = df.loc['title', years].plot(kind = 'line', color = 'r')
plt.title('Immigration from Haiti to Canada from 1980-2013',color = 'black')
plt.xlabel('Years',color = 'black')
plt.ylabel('Number of Immigrants',color = 'black')
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.savefig('linechart_single.png')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_77360\889960967.py in <module>
# ----> 1 fig1 = df.loc['authors', years].plot(kind = 'line', color = 'r')
#       2 plt.title('Immigration from Haiti to Canada from 1980-2013',color = 'black')
#       3 plt.xlabel('Years',color = 'black')
#       4 plt.ylabel('Number of Immigrants',color = 'black')
#       5 plt.xticks(color = 'black')
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1138         with suppress(IndexingError):
#    1139             tup = self._expand_ellipsis(tup)
# -> 1140             return self._getitem_lowerdim(tup)
#    1141
#    1142         # no multi-index, so validate all of the indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     865                 # We don't need to check for tuples here because those are
#     866                 #  caught by the _is_nested_tuple_indexer check above.
# --> 867                 section = self._getitem_axis(key, axis=i)
#     868
#     869                 # We should never have a scalar section here, because
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1203         # fall thru to straight lookup
#    1204         self._validate_key(key, axis)
# -> 1205         return self._get_label(key, axis=axis)
#    1206
#    1207     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1151     def _get_label(self, label, axis: int):
#    1152         # GH#5667 this will fail if the label is not present in the axis.
# -> 1153         return self.obj.xs(label, axis=axis)
#    1154
#    1155     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3862                     new_index = index[loc]
#    3863         else:
# -> 3864             loc = index.get_loc(key)
#    3865
#    3866             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     387                     raise KeyError(key) from err
#     388             self._check_indexing_error(key)
# --> 389             raise KeyError(key)
#     390         return super().get_loc(key, method=method, tolerance=tolerance)
#     391
#
# KeyError: 'authors'

# %% [markdown]
# With your dataframe set up, time to start creating visualizations!

# %%
df_tot = pd.DataFrame({'year'} : years)
df_tot2 = df_tot.value_counts()
# Out:
#   File "C:\Users\Brown\AppData\Local\Temp\ipykernel_77360\204652442.py", line 1
#     df_tot = pd.DataFrame({'year'} : years)
#                                    ^
# SyntaxError: invalid syntax

# %%
# Use your Python skills to create a visualization here.
plt.hist(x=df["year"])
plt.xlabel("Decade of Publication")
plt.ylabel("Number of Books Published")
# Out:
# Text(0, 0.5, 'Number of Books Published')

# %%
# Use your Python skills to create a visualization here.
